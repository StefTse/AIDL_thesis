# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler

from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 


data=pd.read_csv('Emo_Bank_VAD.csv')

print(data.columns)
print('')
print(data.shape)
print(data.head())
print('')
print(data.dtypes)
# Out:
# Index(['id', 'split', 'V', 'A', 'D', 'text'], dtype='object')
#
# (9906, 6)
#                     id  split     V     A     D  \
# 0  110CYL068_1036_1079  train  3.00  3.00  3.20
# 1  110CYL068_1079_1110   test  2.80  3.10  2.80
# 2  110CYL068_1127_1130  train  3.00  3.00  3.00
# 3  110CYL068_1137_1188  train  3.44  3.00  3.22
# 4  110CYL068_1189_1328  train  3.55  3.27  3.46
#
#                                                 text
# 0        Remember what she said in my last letter? "
# 1                          If I wasn't working here.
# 2                                                .."
# 3  Goodwill helps people get off of public assist...
# 4  Sherry learned through our Future Works class ...
#
# id        object
# split     object
# V        float64
# A        float64
# D        float64
# text      object
# dtype: object

# %%
data['text'] = data['text'].fillna("")
data.isnull().sum()
# Out:
# id       0
# split    0
# V        0
# A        0
# D        0
# text     0
# dtype: int64

# %%
# Normalize columns 
scaler = MinMaxScaler(feature_range=(-1, 1))
data[['V', 'A', 'D']] = scaler.fit_transform(data[['V', 'A', 'D']])

print(data.head())

# Split the data
x_train, x_test, y_train, y_test = train_test_split(data["text"], data[["V", "A", "D"]], test_size=0.1, shuffle=True, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, shuffle=True, random_state=1)
print("Data shapes:", x_train.shape, x_val.shape, x_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
#                     id  split         V         A         D  \
# 0  110CYL068_1036_1079  train  0.058824 -0.076923  0.173554
# 1  110CYL068_1079_1110   test -0.058824  0.000000 -0.157025
# 2  110CYL068_1127_1130  train  0.058824 -0.076923  0.008264
# 3  110CYL068_1137_1188  train  0.317647 -0.076923  0.190083
# 4  110CYL068_1189_1328  train  0.382353  0.130769  0.388430
#
#                                                 text
# 0        Remember what she said in my last letter? "
# 1                          If I wasn't working here.
# 2                                                .."
# 3  Goodwill helps people get off of public assist...
# 4  Sherry learned through our Future Works class ...
# Data shapes: (8023,) (892,) (991,) (8023, 3) (892, 3) (991, 3)

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define preprocessing function
def preprocess(text):
    text = text.lower()  # Convert to lower case
    text = word_tokenize(text)  # Tokenize
    text = [w for w in text if w.isalnum() and w not in stop_words]  # Remove stopwords and non-alphanumeric words
    text = " ".join(text)  # Join back into a single string
    text = re.sub(r"[^\w\s]", '', text)  # Remove punctuation
    return text


x_train = x_train.apply(preprocess)
x_val = x_val.apply(preprocess)
x_test = x_test.apply(preprocess)

x_train.head()


# Create word-to-index dictionary and tokenizer
word_to_counts = Counter(" ".join(x_train).split())  
n_words = len(word_to_counts)  

tokenizer = Tokenizer(num_words=n_words, oov_token="<OOV>")
tokenizer.fit_on_texts(x_train)
word_index = tokenizer.word_index

# Convert text data to sequences
x_train_seq = tokenizer.texts_to_sequences(x_train)
x_val_seq = tokenizer.texts_to_sequences(x_val)
x_test_seq = tokenizer.texts_to_sequences(x_test)

max_length = 170

# Pad sequences to the same length
x_train_pad = pad_sequences(x_train_seq, maxlen=max_length)
x_val_pad = pad_sequences(x_val_seq, maxlen=max_length)
x_test_pad = pad_sequences(x_test_seq, maxlen=max_length)

# Convert y data to tensors
y_train = tf.convert_to_tensor(y_train, dtype=tf.float64)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float64)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float64)

print(f"Padded sequence shapes: x_train_pad={x_train_pad.shape}, x_val_pad={x_val_pad.shape}, x_test_pad={x_test_pad.shape}")
print(f"Tensor shapes: y_train={y_train.shape}, y_val={y_val.shape}, y_test={y_test.shape}")

# Create datasets for training, validation, and testing
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_pad, y_train)).shuffle(len(x_train_pad)).batch(32)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_pad, y_val)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_pad, y_test)).batch(32)
# Out:
# [nltk_data] Downloading package punkt to /Users/stef_tse/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/stef_tse/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Padded sequence shapes: x_train_pad=(8023, 170), x_val_pad=(892, 170), x_test_pad=(991, 170)
# Tensor shapes: y_train=(8023, 3), y_val=(892, 3), y_test=(991, 3)
# 2025-01-25 14:40:42.166244: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-01-25 14:40:42.166317: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-01-25 14:40:42.166325: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-01-25 14:40:42.166382: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-01-25 14:40:42.166411: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Bidirectional LSTM model
bi_lstm_VAD_norm = Sequential()
bi_lstm_VAD_norm.add(Embedding(input_dim=n_words, output_dim=128, input_length=max_length))
bi_lstm_VAD_norm.add(Bidirectional(LSTM(128, return_sequences=True)))  # Bidirectional LSTM
bi_lstm_VAD_norm.add(Dropout(0.5))
bi_lstm_VAD_norm.add(Bidirectional(LSTM(64)))  # Bidirectional LSTM
bi_lstm_VAD_norm.add(Dropout(0.5))
bi_lstm_VAD_norm.add(Dense(3, activation='tanh'))  # Activation is tanh for normalized variables
bi_lstm_VAD_norm.summary()

# Compile and train
epochs = 60
optimizer = Adam(learning_rate=0.0001)

keras_callbacks = [EarlyStopping(monitor='val_loss', patience=20, mode='min', min_delta=0.0001), 
                   ModelCheckpoint('best_model_bi_lstm.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1)]

bi_lstm_VAD_norm.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', rmse])
history = bi_lstm_VAD_norm.fit(train_dataset, epochs=epochs, validation_data=val_dataset, callbacks=[keras_callbacks])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 170, 128)          1764736
#
#  bidirectional (Bidirection  (None, 170, 256)          263168
#  al)
#
#  dropout (Dropout)           (None, 170, 256)          0
#
#  bidirectional_1 (Bidirecti  (None, 128)               164352
#  onal)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 3)                 387
#
# =================================================================
# Total params: 2192643 (8.36 MB)
# Trainable params: 2192643 (8.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/60
# 2025-01-25 14:40:55.524185: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:40:56.740151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:40:56.814060: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:40:58.633339: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:40:58.663762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:03.875049: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:03.912436: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:06.078776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:06.118887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 251/251 [==============================] - ETA: 0s - loss: 0.0372 - mae: 0.1415 - rmse: 0.1630
# 2025-01-25 14:41:53.024270: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:53.317999: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:53.337914: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:53.559226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 14:41:53.580315: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_loss improved from inf to 0.03888, saving model to best_model_bi_lstm.h5
# 251/251 [==============================] - 64s 197ms/step - loss: 0.0372 - mae: 0.1415 - rmse: 0.1630 - val_loss: 0.0389 - val_mae: 0.1439 - val_rmse: 0.1662
# Epoch 2/60
# /Users/stef_tse/anaconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 251/251 [==============================] - ETA: 0s - loss: 0.0364 - mae: 0.1393 - rmse: 0.1607
# Epoch 2: val_loss improved from 0.03888 to 0.03832, saving model to best_model_bi_lstm.h5
# 251/251 [==============================] - 49s 196ms/step - loss: 0.0364 - mae: 0.1393 - rmse: 0.1607 - val_loss: 0.0383 - val_mae: 0.1444 - val_rmse: 0.1654
# Epoch 3/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0339 - mae: 0.1343 - rmse: 0.1548
# Epoch 3: val_loss improved from 0.03832 to 0.03700, saving model to best_model_bi_lstm.h5
# 251/251 [==============================] - 45s 181ms/step - loss: 0.0339 - mae: 0.1343 - rmse: 0.1548 - val_loss: 0.0370 - val_mae: 0.1413 - val_rmse: 0.1623
# Epoch 4/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0277 - mae: 0.1216 - rmse: 0.1400
# Epoch 4: val_loss improved from 0.03700 to 0.03655, saving model to best_model_bi_lstm.h5
# 251/251 [==============================] - 51s 204ms/step - loss: 0.0277 - mae: 0.1216 - rmse: 0.1400 - val_loss: 0.0366 - val_mae: 0.1432 - val_rmse: 0.1640
# Epoch 5/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0222 - mae: 0.1077 - rmse: 0.1241
# Epoch 5: val_loss did not improve from 0.03655
# 251/251 [==============================] - 48s 192ms/step - loss: 0.0222 - mae: 0.1077 - rmse: 0.1241 - val_loss: 0.0378 - val_mae: 0.1460 - val_rmse: 0.1671
# Epoch 6/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0184 - mae: 0.0972 - rmse: 0.1123
# Epoch 6: val_loss did not improve from 0.03655
# 251/251 [==============================] - 47s 185ms/step - loss: 0.0184 - mae: 0.0972 - rmse: 0.1123 - val_loss: 0.0374 - val_mae: 0.1459 - val_rmse: 0.1672
# Epoch 7/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0156 - mae: 0.0889 - rmse: 0.1026
# Epoch 7: val_loss did not improve from 0.03655
# 251/251 [==============================] - 49s 194ms/step - loss: 0.0156 - mae: 0.0889 - rmse: 0.1026 - val_loss: 0.0394 - val_mae: 0.1502 - val_rmse: 0.1718
# Epoch 8/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0134 - mae: 0.0815 - rmse: 0.0941
# Epoch 8: val_loss did not improve from 0.03655
# 251/251 [==============================] - 46s 182ms/step - loss: 0.0134 - mae: 0.0815 - rmse: 0.0941 - val_loss: 0.0411 - val_mae: 0.1547 - val_rmse: 0.1772
# Epoch 9/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0117 - mae: 0.0758 - rmse: 0.0875
# Epoch 9: val_loss did not improve from 0.03655
# 251/251 [==============================] - 50s 200ms/step - loss: 0.0117 - mae: 0.0758 - rmse: 0.0875 - val_loss: 0.0429 - val_mae: 0.1579 - val_rmse: 0.1809
# Epoch 10/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0105 - mae: 0.0713 - rmse: 0.0822
# Epoch 10: val_loss did not improve from 0.03655
# 251/251 [==============================] - 50s 200ms/step - loss: 0.0105 - mae: 0.0713 - rmse: 0.0822 - val_loss: 0.0425 - val_mae: 0.1576 - val_rmse: 0.1804
# Epoch 11/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0094 - mae: 0.0666 - rmse: 0.0771
# Epoch 11: val_loss did not improve from 0.03655
# 251/251 [==============================] - 49s 197ms/step - loss: 0.0094 - mae: 0.0666 - rmse: 0.0771 - val_loss: 0.0443 - val_mae: 0.1616 - val_rmse: 0.1851
# Epoch 12/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0086 - mae: 0.0635 - rmse: 0.0732
# Epoch 12: val_loss did not improve from 0.03655
# 251/251 [==============================] - 50s 198ms/step - loss: 0.0086 - mae: 0.0635 - rmse: 0.0732 - val_loss: 0.0456 - val_mae: 0.1640 - val_rmse: 0.1875
# Epoch 13/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0080 - mae: 0.0604 - rmse: 0.0698
# Epoch 13: val_loss did not improve from 0.03655
# 251/251 [==============================] - 44s 173ms/step - loss: 0.0080 - mae: 0.0604 - rmse: 0.0698 - val_loss: 0.0455 - val_mae: 0.1644 - val_rmse: 0.1876
# Epoch 14/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0074 - mae: 0.0578 - rmse: 0.0668
# Epoch 14: val_loss did not improve from 0.03655
# 251/251 [==============================] - 44s 176ms/step - loss: 0.0074 - mae: 0.0578 - rmse: 0.0668 - val_loss: 0.0455 - val_mae: 0.1652 - val_rmse: 0.1886
# Epoch 15/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0070 - mae: 0.0557 - rmse: 0.0644
# Epoch 15: val_loss did not improve from 0.03655
# 251/251 [==============================] - 49s 194ms/step - loss: 0.0070 - mae: 0.0557 - rmse: 0.0644 - val_loss: 0.0466 - val_mae: 0.1671 - val_rmse: 0.1905
# Epoch 16/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0534 - rmse: 0.0618
# Epoch 16: val_loss did not improve from 0.03655
# 251/251 [==============================] - 45s 179ms/step - loss: 0.0066 - mae: 0.0534 - rmse: 0.0618 - val_loss: 0.0475 - val_mae: 0.1695 - val_rmse: 0.1931
# Epoch 17/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0524 - rmse: 0.0605
# Epoch 17: val_loss did not improve from 0.03655
# 251/251 [==============================] - 47s 186ms/step - loss: 0.0064 - mae: 0.0524 - rmse: 0.0605 - val_loss: 0.0473 - val_mae: 0.1687 - val_rmse: 0.1923
# Epoch 18/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0059 - mae: 0.0500 - rmse: 0.0577
# Epoch 18: val_loss did not improve from 0.03655
# 251/251 [==============================] - 46s 184ms/step - loss: 0.0059 - mae: 0.0500 - rmse: 0.0577 - val_loss: 0.0487 - val_mae: 0.1711 - val_rmse: 0.1951
# Epoch 19/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0490 - rmse: 0.0566
# Epoch 19: val_loss did not improve from 0.03655
# 251/251 [==============================] - 42s 166ms/step - loss: 0.0057 - mae: 0.0490 - rmse: 0.0566 - val_loss: 0.0488 - val_mae: 0.1713 - val_rmse: 0.1954
# Epoch 20/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0055 - mae: 0.0481 - rmse: 0.0556
# Epoch 20: val_loss did not improve from 0.03655
# 251/251 [==============================] - 40s 161ms/step - loss: 0.0055 - mae: 0.0481 - rmse: 0.0556 - val_loss: 0.0487 - val_mae: 0.1714 - val_rmse: 0.1953
# Epoch 21/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0467 - rmse: 0.0541
# Epoch 21: val_loss did not improve from 0.03655
# 251/251 [==============================] - 71s 285ms/step - loss: 0.0053 - mae: 0.0467 - rmse: 0.0541 - val_loss: 0.0487 - val_mae: 0.1711 - val_rmse: 0.1954
# Epoch 22/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0456 - rmse: 0.0527
# Epoch 22: val_loss did not improve from 0.03655
# 251/251 [==============================] - 79s 316ms/step - loss: 0.0051 - mae: 0.0456 - rmse: 0.0527 - val_loss: 0.0503 - val_mae: 0.1749 - val_rmse: 0.1991
# Epoch 23/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0049 - mae: 0.0451 - rmse: 0.0522
# Epoch 23: val_loss did not improve from 0.03655
# 251/251 [==============================] - 76s 302ms/step - loss: 0.0049 - mae: 0.0451 - rmse: 0.0522 - val_loss: 0.0509 - val_mae: 0.1760 - val_rmse: 0.2005
# Epoch 24/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0438 - rmse: 0.0506
# Epoch 24: val_loss did not improve from 0.03655
# 251/251 [==============================] - 74s 295ms/step - loss: 0.0048 - mae: 0.0438 - rmse: 0.0506 - val_loss: 0.0513 - val_mae: 0.1764 - val_rmse: 0.2010

# %%
# Load the best saved model
best_bi_lstm_VAD_norm = load_model('best_model_bi_lstm.h5', custom_objects={'rmse': rmse})

# Evaluate the model
train_loss, train_mae, train_rmse = best_bi_lstm_VAD_norm.evaluate(train_dataset)
val_loss, val_mae, val_rmse = best_bi_lstm_VAD_norm.evaluate(val_dataset)
test_loss, test_mae, test_rmse = best_bi_lstm_VAD_norm.evaluate(test_dataset)

# Print evaluation metrics
print("Training Loss:", train_loss)
print("Training MAE:", train_mae)
print("Training RMSE:", train_rmse)

print("Validation Loss:", val_loss)
print("Validation MAE:", val_mae)
print("Validation RMSE:", val_rmse)

print("Testing Loss:", test_loss)
print("Testing MAE:", test_mae)
print("Testing RMSE:", test_rmse)

# Predict on the datasets
y_train_pred = best_bi_lstm_VAD_norm.predict(x_train_pad)
y_val_pred = best_bi_lstm_VAD_norm.predict(x_val_pad)
y_test_pred = best_bi_lstm_VAD_norm.predict(x_test_pad)

# Compute and print detailed metrics for each target variable (V, A, D)
for i, target in enumerate(["V", "A", "D"]):
    print(f"\nMetrics for target variable {target}:")
    
    y_train_true = y_train[:, i].numpy()
    y_train_pred_target = y_train_pred[:, i]
    train_mse = mean_squared_error(y_train_true, y_train_pred_target)
    train_mae = mean_absolute_error(y_train_true, y_train_pred_target)
    train_rmse = np.sqrt(train_mse)
    print(f"Train {target} - MSE: {train_mse:.2f}")
    print(f"Train {target} - MAE: {train_mae:.2f}")
    print(f"Train {target} - RMSE: {train_rmse:.2f}")

    y_val_true = y_val[:, i].numpy()
    y_val_pred_target = y_val_pred[:, i]
    val_mse = mean_squared_error(y_val_true, y_val_pred_target)
    val_mae = mean_absolute_error(y_val_true, y_val_pred_target)
    val_rmse = np.sqrt(val_mse)
    print(f"Validation {target} - MSE: {val_mse:.2f}")
    print(f"Validation {target} - MAE: {val_mae:.2f}")
    print(f"Validation {target} - RMSE: {val_rmse:.2f}")

    y_test_true = y_test[:, i].numpy()
    y_test_pred_target = y_test_pred[:, i]
    test_mse = mean_squared_error(y_test_true, y_test_pred_target)
    test_mae = mean_absolute_error(y_test_true, y_test_pred_target)
    test_rmse = np.sqrt(test_mse)
    print(f"Test {target} - MSE: {test_mse:.2f}")
    print(f"Test {target} - MAE: {test_mae:.2f}")
    print(f"Test {target} - RMSE: {test_rmse:.2f}")
# Out:
# 2025-01-25 15:04:58.064764: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:04:58.705529: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:04:58.751302: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:04:59.214840: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:04:59.293309: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 251/251 [==============================] - 28s 96ms/step - loss: 0.0220 - mae: 0.1054 - rmse: 0.1218
# 28/28 [==============================] - 3s 106ms/step - loss: 0.0366 - mae: 0.1432 - rmse: 0.1640
# 31/31 [==============================] - 3s 112ms/step - loss: 0.0368 - mae: 0.1422 - rmse: 0.1626
# Training Loss: 0.022035324946045876
# Training MAE: 0.10537556558847427
# Training RMSE: 0.12184764444828033
# Validation Loss: 0.036552708595991135
# Validation MAE: 0.14316046237945557
# Validation RMSE: 0.1640455573797226
# Testing Loss: 0.03684665635228157
# Testing MAE: 0.1421830654144287
# Testing RMSE: 0.16264688968658447
# 2025-01-25 15:05:33.142898: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:05:33.755602: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:05:33.807388: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:05:34.262562: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-01-25 15:05:34.305491: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 251/251 [==============================] - 24s 81ms/step
# 28/28 [==============================] - 2s 87ms/step
# 31/31 [==============================] - 2s 77ms/step
#
# Metrics for target variable V:
# Train V - MSE: 0.02
# Train V - MAE: 0.10
# Train V - RMSE: 0.14
# Validation V - MSE: 0.04
# Validation V - MAE: 0.14
# Validation V - RMSE: 0.19
# Test V - MSE: 0.04
# Test V - MAE: 0.14
# Test V - RMSE: 0.19
#
# Metrics for target variable A:
# Train A - MSE: 0.02
# Train A - MAE: 0.11
# Train A - RMSE: 0.15
# Validation A - MSE: 0.04
# Validation A - MAE: 0.15
# Validation A - RMSE: 0.20
# Test A - MSE: 0.04
# Test A - MAE: 0.15
# Test A - RMSE: 0.20
#
# Metrics for target variable D:
# Train D - MSE: 0.02
# Train D - MAE: 0.11
# Train D - RMSE: 0.15
# Validation D - MSE: 0.03
# Validation D - MAE: 0.14
# Validation D - RMSE: 0.18
# Test D - MSE: 0.03
# Test D - MAE: 0.13
# Test D - RMSE: 0.18

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot for true vs predicted
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot true values
ax.scatter(y_test[:, 0], y_test[:, 1], y_test[:, 2], c='b', marker='o', label='True Values')
# Plot predicted values
ax.scatter(y_test_pred[:, 0], y_test_pred[:, 1], y_test_pred[:, 2], c='r', marker='^', label='Predicted Values')

# Set axes limits to [-1, 1]
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_zlim([-1, 1])

ax.set_xlabel('V')
ax.set_ylabel('A')
ax.set_zlabel('D')
ax.set_title('True vs Predicted Values for V, A, and D')
ax.legend()

plt.show()

# %%
plt.figure(figsize=(14, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)

# MAE Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot training & validation RMSE
plt.figure(figsize=(7, 6))

# RMSE Plot
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Val RMSE')
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)

plt.show()

# %%
# Calculate residuals
residuals = y_test - y_test_pred

# Plot True Values vs Predictions
fig, axes = plt.subplots(3, 2, figsize=(15, 15))
axes = axes.flatten()
targets = ["V", "A", "D"]

for i, target in enumerate(targets):
    # True vs Predicted Values
    axes[i].scatter(y_test[:, i], y_test_pred[:, i], alpha=0.5, label='Predicted Values')
    axes[i].plot([min(y_test[:, i]), max(y_test[:, i])], [min(y_test[:, i]), max(y_test[:, i])], 'r--', label='Ideal Fit')
    axes[i].set_xlabel(f'True {target}')
    axes[i].set_ylabel(f'Predicted {target}')
    axes[i].set_title(f'True vs Predicted {target}')
    axes[i].legend()

for i, target in enumerate(targets):
    # Residuals Plot
    axes[i + 3].scatter(y_test[:, i], residuals[:, i], alpha=0.5)
    axes[i + 3].hlines(0, min(y_test[:, i]), max(y_test[:, i]), colors='r', linestyles='dashed')
    axes[i + 3].set_xlabel(f'True {target}')
    axes[i + 3].set_ylabel(f'Residuals {target}')
    axes[i + 3].set_title(f'Residuals for {target}')

plt.tight_layout()
plt.show()

# %%
# Create DataFrames for each dataset and target variable
for i, target in enumerate(["V", "A", "D"]):
    df_train = pd.DataFrame({
        'Text': x_train.values,
        f'True_{target}': y_train[:, i],
        f'Predicted_{target}': y_train_pred[:, i]
    })
    df_val = pd.DataFrame({
        'Text': x_val.values,
        f'True_{target}': y_val[:, i],
        f'Predicted_{target}': y_val_pred[:, i]
    })
    df_test = pd.DataFrame({
        'Text': x_test.values,
        f'True_{target}': y_test[:, i],
        f'Predicted_{target}': y_test_pred[:, i]
    })


    print(f"\nSample DataFrame for train set, target variable {target}:")
    print(df_train.head())

    print(f"\nSample DataFrame for validation set, target variable {target}:")
    print(df_val.head())

    print(f"\nSample DataFrame for test set, target variable {target}:")
    print(df_test.head())
# Out:
# Sample DataFrame for train set, target variable V:
#                                                 Text    True_V  Predicted_V
# 0                                    asean talks end  0.058824     0.040465
# 1                 antibiotic ketek dangerous thought -0.235294    -0.210724
# 2                  death throughout death everywhere -0.352941    -0.142117
# 3  fascinating collection artifacts pertaining sh...  0.388235     0.241126
# 4  rat pack originally frank sinatra dean martin ...  0.058824     0.038224
#
# Sample DataFrame for validation set, target variable V:
#                                                 Text        True_V  \
# 0                                   could free tasha  1.176471e-01
# 1  differences western native perceptions lead co...  2.220446e-16
# 2                 going shed little blood worry none  5.882353e-02
# 3              simplicity dress seen mark modern man  1.235294e-01
# 4                                          100 house  5.882353e-02
#
#    Predicted_V
# 0     0.061616
# 1    -0.041500
# 2    -0.226187
# 3     0.024398
# 4     0.018400
#
# Sample DataFrame for test set, target variable V:
#                                                 Text        True_V  \
# 0                                             silent  2.220446e-16
# 1  overriding governor tony knowles veto ignoring... -1.764706e-01
# 2  backwards recapitulation technique bartók empl...  5.882353e-02
# 3                                    maybe month two  2.220446e-16
# 4  marched regiments practiced ranks followed lea...  5.882353e-02
#
#    Predicted_V
# 0     0.013468
# 1    -0.130980
# 2     0.073538
# 3    -0.013249
# 4    -0.029403
#
# Sample DataFrame for train set, target variable A:
#                                                 Text    True_A  Predicted_A
# 0                                    asean talks end -0.307692    -0.119290
# 1                 antibiotic ketek dangerous thought  0.000000    -0.033690
# 2                  death throughout death everywhere  0.000000     0.021609
# 3  fascinating collection artifacts pertaining sh...  0.176923    -0.002192
# 4  rat pack originally frank sinatra dean martin ... -0.076923    -0.157207
#
# Sample DataFrame for validation set, target variable A:
#                                                 Text    True_A  Predicted_A
# 0                                   could free tasha  0.000000     0.045702
# 1  differences western native perceptions lead co... -0.153846    -0.113307
# 2                 going shed little blood worry none  0.253846     0.047424
# 3              simplicity dress seen mark modern man -0.076923    -0.065825
# 4                                          100 house  0.076923     0.014715
#
# Sample DataFrame for test set, target variable A:
#                                                 Text    True_A  Predicted_A
# 0                                             silent -0.692308     0.008273
# 1  overriding governor tony knowles veto ignoring...  0.076923    -0.133892
# 2  backwards recapitulation technique bartók empl... -0.184615    -0.194849
# 3                                    maybe month two -0.307692    -0.093843
# 4  marched regiments practiced ranks followed lea... -0.246154    -0.178152
#
# Sample DataFrame for train set, target variable D:
#                                                 Text    True_D  Predicted_D
# 0                                    asean talks end  0.090909     0.043156
# 1                 antibiotic ketek dangerous thought -0.157025    -0.072279
# 2                  death throughout death everywhere -0.157025    -0.011396
# 3  fascinating collection artifacts pertaining sh...  0.099174     0.139357
# 4  rat pack originally frank sinatra dean martin ...  0.008264    -0.002304
#
# Sample DataFrame for validation set, target variable D:
#                                                 Text    True_D  Predicted_D
# 0                                   could free tasha  0.669421     0.086351
# 1  differences western native perceptions lead co... -0.074380    -0.003146
# 2                 going shed little blood worry none  0.363636    -0.056331
# 3              simplicity dress seen mark modern man  0.190083     0.019402
# 4                                          100 house  0.090909     0.067439
#
# Sample DataFrame for test set, target variable D:
#                                                 Text    True_D  Predicted_D
# 0                                             silent -0.074380     0.063097
# 1  overriding governor tony knowles veto ignoring... -0.074380    -0.051599
# 2  backwards recapitulation technique bartók empl...  0.008264     0.043553
# 3                                    maybe month two  0.090909     0.021163
# 4  marched regiments practiced ranks followed lea...  0.008264    -0.010500

# %%
# Save DataFrames to CSV files
df_train.to_csv(f'train_{target}_comparison_bi_lstm_VAD_norm.csv', index=False)
df_val.to_csv(f'val_{target}_comparison_bi_lstm_VAD_norm.csv', index=False)
df_test.to_csv(f'test_{target}_comparison_bi_lstm_VAD_norm.csv', index=False)
