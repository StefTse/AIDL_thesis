# %% [markdown]
# ### LSTM for predicting V, A and D

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import re

from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MeanAbsoluteError
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils
import keras.backend as K
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def rmse(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 


data=pd.read_csv('Emo_Bank_VAD.csv')

print(data.columns)
print('')
print(data.shape)
print(data.head())
print('')
print(data.dtypes)
# Out:
# Index(['id', 'split', 'V', 'A', 'D', 'text'], dtype='object')
#
# (9906, 6)
#                     id  split     V     A     D  \
# 0  110CYL068_1036_1079  train  3.00  3.00  3.20
# 1  110CYL068_1079_1110   test  2.80  3.10  2.80
# 2  110CYL068_1127_1130  train  3.00  3.00  3.00
# 3  110CYL068_1137_1188  train  3.44  3.00  3.22
# 4  110CYL068_1189_1328  train  3.55  3.27  3.46
#
#                                                 text
# 0        Remember what she said in my last letter? "
# 1                          If I wasn't working here.
# 2                                                .."
# 3  Goodwill helps people get off of public assist...
# 4  Sherry learned through our Future Works class ...
#
# id        object
# split     object
# V        float64
# A        float64
# D        float64
# text      object
# dtype: object

# %%
data.isnull().sum()
# Out:
# id       0
# split    0
# V        0
# A        0
# D        0
# text     0
# dtype: int64

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(data["text"], data[["V", "A", "D"]], test_size=0.1, shuffle=True, random_state=1)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, shuffle=True, random_state=1)
print("Data shapes:", x_train.shape, x_val.shape, x_test.shape, y_train.shape, y_val.shape, y_test.shape)
# Out:
# Data shapes: (8023,) (892,) (991,) (8023, 3) (892, 3) (991, 3)

# %%
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define preprocessing function
def preprocess(text):
    text = text.lower()  # Convert to lower case
    text = word_tokenize(text)  # Tokenize
    text = [w for w in text if w.isalnum() and w not in stop_words]  # Remove stopwords and non-alphanumeric words
    text = " ".join(text)  # Join back into a single string
    text = re.sub(r"[^\w\s]", '', text)  # Remove punctuation
    return text


x_train = x_train.apply(preprocess)
x_val = x_val.apply(preprocess)
x_test = x_test.apply(preprocess)

x_train.head()
# Out:
# [nltk_data] Downloading package punkt to /Users/stef_tse/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/stef_tse/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 5214                                      asean talks end
# 4784                   antibiotic ketek dangerous thought
# 708                     death throughout death everywhere
# 6369    fascinating collection artifacts pertaining sh...
# 2135    rat pack originally frank sinatra dean martin ...
# Name: text, dtype: object

# %%
# Create word-to-index dictionary and tokenizer
word_to_counts = Counter(" ".join(x_train).split())  
n_words = len(word_to_counts)  

tokenizer = Tokenizer(num_words=n_words, oov_token="<OOV>")
tokenizer.fit_on_texts(x_train)
word_index = tokenizer.word_index

# Convert text data to sequences
x_train_seq = tokenizer.texts_to_sequences(x_train)
x_val_seq = tokenizer.texts_to_sequences(x_val)
x_test_seq = tokenizer.texts_to_sequences(x_test)

max_length = 170

# Pad sequences to the same length
x_train_pad = pad_sequences(x_train_seq, maxlen=max_length)
x_val_pad = pad_sequences(x_val_seq, maxlen=max_length)
x_test_pad = pad_sequences(x_test_seq, maxlen=max_length)

# Convert y data to tensors
y_train = tf.convert_to_tensor(y_train, dtype=tf.float64)
y_val = tf.convert_to_tensor(y_val, dtype=tf.float64)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float64)

print(f"Padded sequence shapes: x_train_pad={x_train_pad.shape}, x_val_pad={x_val_pad.shape}, x_test_pad={x_test_pad.shape}")
print(f"Tensor shapes: y_train={y_train.shape}, y_val={y_val.shape}, y_test={y_test.shape}")

# Create datasets for training, validation, and testing
train_dataset = tf.data.Dataset.from_tensor_slices((x_train_pad, y_train)).shuffle(len(x_train_pad)).batch(32)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val_pad, y_val)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test_pad, y_test)).batch(32)
# Out:
# Metal device set to: Apple M1
# Padded sequence shapes: x_train_pad=(8023, 170), x_val_pad=(892, 170), x_test_pad=(991, 170)
# Tensor shapes: y_train=(8023, 3), y_val=(892, 3), y_test=(991, 3)
# 2024-07-14 19:41:00.716035: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-14 19:41:00.716054: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Build the LSTM model
lstm_VAD = Sequential()
lstm_VAD.add(Embedding(input_dim=7880, output_dim=128, input_length=max_length))
lstm_VAD.add(LSTM(128, return_sequences=True))
lstm_VAD.add(Dropout(0.2))
lstm_VAD.add(LSTM(64))
lstm_VAD.add(Dropout(0.2))
lstm_VAD.add(Dense(3, activation='linear'))
lstm_VAD.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 170, 128)          1008640
#
#  lstm (LSTM)                 (None, 170, 128)          131584
#
#  dropout (Dropout)           (None, 170, 128)          0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 3)                 195
#
# =================================================================
# Total params: 1189827 (4.54 MB)
# Trainable params: 1189827 (4.54 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#compile and train

epochs = 60
batch_size=32
optimizer = Adam(learning_rate=0.0001)


keras_callbacks = [EarlyStopping(monitor='val_loss', patience=20, mode='min', min_delta=0.0001), ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min',verbose=1)]

lstm_VAD.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae', rmse])
history = lstm_VAD.fit(train_dataset, batch_size=batch_size, epochs=epochs, validation_data=val_dataset, callbacks=[keras_callbacks])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/60
# 2024-07-14 19:41:40.927249: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 251/251 [==============================] - ETA: 0s - loss: 1.6711 - mae: 0.8505 - rmse: 0.9022
# Epoch 1: val_loss improved from inf to 0.08672, saving model to best_model.h5
# 251/251 [==============================] - 26s 86ms/step - loss: 1.6711 - mae: 0.8505 - rmse: 0.9022 - val_loss: 0.0867 - val_mae: 0.2142 - val_rmse: 0.2461
# Epoch 2/60
#   2/251 [..............................] - ETA: 19s - loss: 0.1438 - mae: 0.3080 - rmse: 0.3533
# /Users/stef_tse/anaconda3/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 251/251 [==============================] - ETA: 0s - loss: 0.1407 - mae: 0.2921 - rmse: 0.3369
# Epoch 2: val_loss improved from 0.08672 to 0.08179, saving model to best_model.h5
# 251/251 [==============================] - 19s 77ms/step - loss: 0.1407 - mae: 0.2921 - rmse: 0.3369 - val_loss: 0.0818 - val_mae: 0.2056 - val_rmse: 0.2408
# Epoch 3/60
# 251/251 [==============================] - ETA: 0s - loss: 0.1013 - mae: 0.2393 - rmse: 0.2761
# Epoch 3: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 58ms/step - loss: 0.1013 - mae: 0.2393 - rmse: 0.2761 - val_loss: 0.0889 - val_mae: 0.2189 - val_rmse: 0.2524
# Epoch 4/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0861 - mae: 0.2152 - rmse: 0.2497
# Epoch 4: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 60ms/step - loss: 0.0861 - mae: 0.2152 - rmse: 0.2497 - val_loss: 0.0838 - val_mae: 0.2107 - val_rmse: 0.2442
# Epoch 5/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0804 - mae: 0.2042 - rmse: 0.2378
# Epoch 5: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 58ms/step - loss: 0.0804 - mae: 0.2042 - rmse: 0.2378 - val_loss: 0.0895 - val_mae: 0.2176 - val_rmse: 0.2515
# Epoch 6/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0785 - mae: 0.2012 - rmse: 0.2342
# Epoch 6: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 59ms/step - loss: 0.0785 - mae: 0.2012 - rmse: 0.2342 - val_loss: 0.0887 - val_mae: 0.2175 - val_rmse: 0.2510
# Epoch 7/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0777 - mae: 0.1997 - rmse: 0.2328
# Epoch 7: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 60ms/step - loss: 0.0777 - mae: 0.1997 - rmse: 0.2328 - val_loss: 0.0841 - val_mae: 0.2079 - val_rmse: 0.2413
# Epoch 8/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0774 - mae: 0.1993 - rmse: 0.2323
# Epoch 8: val_loss did not improve from 0.08179
# 251/251 [==============================] - 15s 59ms/step - loss: 0.0774 - mae: 0.1993 - rmse: 0.2323 - val_loss: 0.0824 - val_mae: 0.2078 - val_rmse: 0.2412
# Epoch 9/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0764 - mae: 0.1975 - rmse: 0.2305
# Epoch 9: val_loss improved from 0.08179 to 0.08093, saving model to best_model.h5
# 251/251 [==============================] - 17s 69ms/step - loss: 0.0764 - mae: 0.1975 - rmse: 0.2305 - val_loss: 0.0809 - val_mae: 0.2040 - val_rmse: 0.2378
# Epoch 10/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0748 - mae: 0.1954 - rmse: 0.2281
# Epoch 10: val_loss did not improve from 0.08093
# 251/251 [==============================] - 20s 78ms/step - loss: 0.0748 - mae: 0.1954 - rmse: 0.2281 - val_loss: 0.0810 - val_mae: 0.2050 - val_rmse: 0.2380
# Epoch 11/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0713 - mae: 0.1915 - rmse: 0.2231
# Epoch 11: val_loss improved from 0.08093 to 0.07724, saving model to best_model.h5
# 251/251 [==============================] - 20s 78ms/step - loss: 0.0713 - mae: 0.1915 - rmse: 0.2231 - val_loss: 0.0772 - val_mae: 0.2009 - val_rmse: 0.2326
# Epoch 12/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0646 - mae: 0.1834 - rmse: 0.2130
# Epoch 12: val_loss improved from 0.07724 to 0.07362, saving model to best_model.h5
# 251/251 [==============================] - 20s 78ms/step - loss: 0.0646 - mae: 0.1834 - rmse: 0.2130 - val_loss: 0.0736 - val_mae: 0.1985 - val_rmse: 0.2291
# Epoch 13/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0591 - mae: 0.1767 - rmse: 0.2045
# Epoch 13: val_loss improved from 0.07362 to 0.07259, saving model to best_model.h5
# 251/251 [==============================] - 20s 81ms/step - loss: 0.0591 - mae: 0.1767 - rmse: 0.2045 - val_loss: 0.0726 - val_mae: 0.1981 - val_rmse: 0.2297
# Epoch 14/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0548 - mae: 0.1707 - rmse: 0.1973
# Epoch 14: val_loss did not improve from 0.07259
# 251/251 [==============================] - 21s 85ms/step - loss: 0.0548 - mae: 0.1707 - rmse: 0.1973 - val_loss: 0.0736 - val_mae: 0.2005 - val_rmse: 0.2306
# Epoch 15/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0513 - mae: 0.1653 - rmse: 0.1912
# Epoch 15: val_loss did not improve from 0.07259
# 251/251 [==============================] - 22s 88ms/step - loss: 0.0513 - mae: 0.1653 - rmse: 0.1912 - val_loss: 0.0806 - val_mae: 0.2123 - val_rmse: 0.2435
# Epoch 16/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0476 - mae: 0.1588 - rmse: 0.1835
# Epoch 16: val_loss did not improve from 0.07259
# 251/251 [==============================] - 23s 91ms/step - loss: 0.0476 - mae: 0.1588 - rmse: 0.1835 - val_loss: 0.0814 - val_mae: 0.2152 - val_rmse: 0.2463
# Epoch 17/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0450 - mae: 0.1547 - rmse: 0.1788
# Epoch 17: val_loss did not improve from 0.07259
# 251/251 [==============================] - 23s 93ms/step - loss: 0.0450 - mae: 0.1547 - rmse: 0.1788 - val_loss: 0.0750 - val_mae: 0.2040 - val_rmse: 0.2348
# Epoch 18/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0429 - mae: 0.1513 - rmse: 0.1746
# Epoch 18: val_loss did not improve from 0.07259
# 251/251 [==============================] - 24s 94ms/step - loss: 0.0429 - mae: 0.1513 - rmse: 0.1746 - val_loss: 0.0762 - val_mae: 0.2071 - val_rmse: 0.2381
# Epoch 19/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0403 - mae: 0.1455 - rmse: 0.1681
# Epoch 19: val_loss did not improve from 0.07259
# 251/251 [==============================] - 24s 97ms/step - loss: 0.0403 - mae: 0.1455 - rmse: 0.1681 - val_loss: 0.0815 - val_mae: 0.2177 - val_rmse: 0.2492
# Epoch 20/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0387 - mae: 0.1428 - rmse: 0.1651
# Epoch 20: val_loss did not improve from 0.07259
# 251/251 [==============================] - 24s 95ms/step - loss: 0.0387 - mae: 0.1428 - rmse: 0.1651 - val_loss: 0.0860 - val_mae: 0.2206 - val_rmse: 0.2537
# Epoch 21/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0367 - mae: 0.1387 - rmse: 0.1605
# Epoch 21: val_loss did not improve from 0.07259
# 251/251 [==============================] - 24s 96ms/step - loss: 0.0367 - mae: 0.1387 - rmse: 0.1605 - val_loss: 0.0955 - val_mae: 0.2342 - val_rmse: 0.2688
# Epoch 22/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0355 - mae: 0.1357 - rmse: 0.1571
# Epoch 22: val_loss did not improve from 0.07259
# 251/251 [==============================] - 25s 98ms/step - loss: 0.0355 - mae: 0.1357 - rmse: 0.1571 - val_loss: 0.0851 - val_mae: 0.2211 - val_rmse: 0.2534
# Epoch 23/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0339 - mae: 0.1323 - rmse: 0.1532
# Epoch 23: val_loss did not improve from 0.07259
# 251/251 [==============================] - 25s 101ms/step - loss: 0.0339 - mae: 0.1323 - rmse: 0.1532 - val_loss: 0.0994 - val_mae: 0.2413 - val_rmse: 0.2755
# Epoch 24/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0323 - mae: 0.1290 - rmse: 0.1491
# Epoch 24: val_loss did not improve from 0.07259
# 251/251 [==============================] - 25s 101ms/step - loss: 0.0323 - mae: 0.1290 - rmse: 0.1491 - val_loss: 0.0903 - val_mae: 0.2264 - val_rmse: 0.2607
# Epoch 25/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0310 - mae: 0.1258 - rmse: 0.1457
# Epoch 25: val_loss did not improve from 0.07259
# 251/251 [==============================] - 26s 103ms/step - loss: 0.0310 - mae: 0.1258 - rmse: 0.1457 - val_loss: 0.0913 - val_mae: 0.2304 - val_rmse: 0.2634
# Epoch 26/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0299 - mae: 0.1234 - rmse: 0.1425
# Epoch 26: val_loss did not improve from 0.07259
# 251/251 [==============================] - 26s 104ms/step - loss: 0.0299 - mae: 0.1234 - rmse: 0.1425 - val_loss: 0.0978 - val_mae: 0.2385 - val_rmse: 0.2733
# Epoch 27/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0291 - mae: 0.1211 - rmse: 0.1404
# Epoch 27: val_loss did not improve from 0.07259
# 251/251 [==============================] - 27s 106ms/step - loss: 0.0291 - mae: 0.1211 - rmse: 0.1404 - val_loss: 0.0961 - val_mae: 0.2376 - val_rmse: 0.2721
# Epoch 28/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0278 - mae: 0.1186 - rmse: 0.1370
# Epoch 28: val_loss did not improve from 0.07259
# 251/251 [==============================] - 27s 106ms/step - loss: 0.0278 - mae: 0.1186 - rmse: 0.1370 - val_loss: 0.0950 - val_mae: 0.2349 - val_rmse: 0.2694
# Epoch 29/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0268 - mae: 0.1165 - rmse: 0.1348
# Epoch 29: val_loss did not improve from 0.07259
# 251/251 [==============================] - 27s 107ms/step - loss: 0.0268 - mae: 0.1165 - rmse: 0.1348 - val_loss: 0.1051 - val_mae: 0.2514 - val_rmse: 0.2861
# Epoch 30/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0253 - mae: 0.1120 - rmse: 0.1296
# Epoch 30: val_loss did not improve from 0.07259
# 251/251 [==============================] - 28s 111ms/step - loss: 0.0253 - mae: 0.1120 - rmse: 0.1296 - val_loss: 0.0979 - val_mae: 0.2414 - val_rmse: 0.2761
# Epoch 31/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0246 - mae: 0.1098 - rmse: 0.1271
# Epoch 31: val_loss did not improve from 0.07259
# 251/251 [==============================] - 27s 108ms/step - loss: 0.0246 - mae: 0.1098 - rmse: 0.1271 - val_loss: 0.1032 - val_mae: 0.2480 - val_rmse: 0.2834
# Epoch 32/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0237 - mae: 0.1082 - rmse: 0.1250
# Epoch 32: val_loss did not improve from 0.07259
# 251/251 [==============================] - 27s 109ms/step - loss: 0.0237 - mae: 0.1082 - rmse: 0.1250 - val_loss: 0.1033 - val_mae: 0.2473 - val_rmse: 0.2832
# Epoch 33/60
# 251/251 [==============================] - ETA: 0s - loss: 0.0231 - mae: 0.1064 - rmse: 0.1230
# Epoch 33: val_loss did not improve from 0.07259
# 251/251 [==============================] - 23s 93ms/step - loss: 0.0231 - mae: 0.1064 - rmse: 0.1230 - val_loss: 0.1023 - val_mae: 0.2451 - val_rmse: 0.2815

# %%
# Load the best saved model
best_lstm_VAD = load_model('best_model.h5', custom_objects={'rmse': rmse})

# Evaluate the model
train_loss, train_mae, train_rmse = best_lstm_VAD.evaluate(train_dataset)
val_loss, val_mae, val_rmse = best_lstm_VAD.evaluate(val_dataset)
test_loss, test_mae, test_rmse = best_lstm_VAD.evaluate(test_dataset)

# Print evaluation metrics
print("Training Loss:", train_loss)
print("Training MAE:", train_mae)
print("Training RMSE:", train_rmse)

print("Validation Loss:", val_loss)
print("Validation MAE:", val_mae)
print("Validation RMSE:", val_rmse)

print("Testing Loss:", test_loss)
print("Testing MAE:", test_mae)
print("Testing RMSE:", test_rmse)

# Predict on the datasets
y_train_pred = best_lstm_VAD.predict(x_train_pad)
y_val_pred = best_lstm_VAD.predict(x_val_pad)
y_test_pred = best_lstm_VAD.predict(x_test_pad)

# Compute and print detailed metrics for each target variable (V, A, D)
for i, target in enumerate(["V", "A", "D"]):
    print(f"\nMetrics for target variable {target}:")
    
    y_train_true = y_train[:, i].numpy()
    y_train_pred_target = y_train_pred[:, i]
    train_mse = mean_squared_error(y_train_true, y_train_pred_target)
    train_mae = mean_absolute_error(y_train_true, y_train_pred_target)
    train_rmse = np.sqrt(train_mse)
    print(f"Train {target} - MSE: {train_mse:.2f}")
    print(f"Train {target} - MAE: {train_mae:.2f}")
    print(f"Train {target} - RMSE: {train_rmse:.2f}")

    y_val_true = y_val[:, i].numpy()
    y_val_pred_target = y_val_pred[:, i]
    val_mse = mean_squared_error(y_val_true, y_val_pred_target)
    val_mae = mean_absolute_error(y_val_true, y_val_pred_target)
    val_rmse = np.sqrt(val_mse)
    print(f"Validation {target} - MSE: {val_mse:.2f}")
    print(f"Validation {target} - MAE: {val_mae:.2f}")
    print(f"Validation {target} - RMSE: {val_rmse:.2f}")

    y_test_true = y_test[:, i].numpy()
    y_test_pred_target = y_test_pred[:, i]
    test_mse = mean_squared_error(y_test_true, y_test_pred_target)
    test_mae = mean_absolute_error(y_test_true, y_test_pred_target)
    test_rmse = np.sqrt(test_mse)
    print(f"Test {target} - MSE: {test_mse:.2f}")
    print(f"Test {target} - MAE: {test_mae:.2f}")
    print(f"Test {target} - RMSE: {test_rmse:.2f}")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 251/251 [==============================] - 4s 14ms/step - loss: 0.0532 - mae: 0.1678 - rmse: 0.1950
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0726 - mae: 0.1981 - rmse: 0.2297
# 31/31 [==============================] - 1s 18ms/step - loss: 0.0728 - mae: 0.1986 - rmse: 0.2295
# Training Loss: 0.053246330469846725
# Training MAE: 0.16777247190475464
# Training RMSE: 0.19499288499355316
# Validation Loss: 0.07259224355220795
# Validation MAE: 0.19806545972824097
# Validation RMSE: 0.22970522940158844
# Testing Loss: 0.07284712046384811
# Testing MAE: 0.19862088561058044
# Testing RMSE: 0.22949916124343872
# 251/251 [==============================] - 3s 10ms/step
# 28/28 [==============================] - 0s 12ms/step
# 31/31 [==============================] - 0s 11ms/step
#
# Metrics for target variable V:
# Train V - MSE: 0.06
# Train V - MAE: 0.17
# Train V - RMSE: 0.25
# Validation V - MSE: 0.10
# Validation V - MAE: 0.23
# Validation V - RMSE: 0.32
# Test V - MSE: 0.10
# Test V - MAE: 0.23
# Test V - RMSE: 0.32
#
# Metrics for target variable A:
# Train A - MSE: 0.06
# Train A - MAE: 0.19
# Train A - RMSE: 0.25
# Validation A - MSE: 0.07
# Validation A - MAE: 0.20
# Validation A - RMSE: 0.26
# Test A - MSE: 0.07
# Test A - MAE: 0.20
# Test A - RMSE: 0.27
#
# Metrics for target variable D:
# Train D - MSE: 0.04
# Train D - MAE: 0.14
# Train D - RMSE: 0.19
# Validation D - MSE: 0.05
# Validation D - MAE: 0.16
# Validation D - RMSE: 0.22
# Test D - MSE: 0.05
# Test D - MAE: 0.16
# Test D - RMSE: 0.22

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot for true vs predicted
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(y_test[:, 0], y_test[:, 1], y_test[:, 2], c='b', marker='o', label='True Values')
ax.scatter(y_test_pred[:, 0], y_test_pred[:, 1], y_test_pred[:, 2], c='r', marker='^', label='Predicted Values')

ax.set_xlabel('V')
ax.set_ylabel('A')
ax.set_zlabel('D')
ax.set_title('True vs Predicted Values for V, A, and D')
ax.legend()

plt.show()

# %%
plt.figure(figsize=(14, 6))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)

# MAE Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot training & validation RMSE
plt.figure(figsize=(7, 6))

# RMSE Plot
plt.plot(history.history['rmse'], label='Train RMSE')
plt.plot(history.history['val_rmse'], label='Val RMSE')
plt.title('Model RMSE')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid(True)

plt.show()

# %%
# Calculate residuals
residuals = y_test - y_test_pred

# Plot True Values vs Predictions
fig, axes = plt.subplots(3, 2, figsize=(15, 15))
axes = axes.flatten()
targets = ["V", "A", "D"]

for i, target in enumerate(targets):
    # True vs Predicted Values
    axes[i].scatter(y_test[:, i], y_test_pred[:, i], alpha=0.5, label='Predicted Values')
    axes[i].plot([min(y_test[:, i]), max(y_test[:, i])], [min(y_test[:, i]), max(y_test[:, i])], 'r--', label='Ideal Fit')
    axes[i].set_xlabel(f'True {target}')
    axes[i].set_ylabel(f'Predicted {target}')
    axes[i].set_title(f'True vs Predicted {target}')
    axes[i].legend()

for i, target in enumerate(targets):
    # Residuals Plot
    axes[i + 3].scatter(y_test[:, i], residuals[:, i], alpha=0.5)
    axes[i + 3].hlines(0, min(y_test[:, i]), max(y_test[:, i]), colors='r', linestyles='dashed')
    axes[i + 3].set_xlabel(f'True {target}')
    axes[i + 3].set_ylabel(f'Residuals {target}')
    axes[i + 3].set_title(f'Residuals for {target}')

plt.tight_layout()
plt.show()

# %%
# Create DataFrames for each dataset and target variable
for i, target in enumerate(["V", "A", "D"]):
    df_train = pd.DataFrame({
        'Text': x_train.values,
        f'True_{target}': y_train[:, i],
        f'Predicted_{target}': y_train_pred[:, i]
    })
    df_val = pd.DataFrame({
        'Text': x_val.values,
        f'True_{target}': y_val[:, i],
        f'Predicted_{target}': y_val_pred[:, i]
    })
    df_test = pd.DataFrame({
        'Text': x_test.values,
        f'True_{target}': y_test[:, i],
        f'Predicted_{target}': y_test_pred[:, i]
    })


    print(f"\nSample DataFrame for train set, target variable {target}:")
    print(df_train.head())

    print(f"\nSample DataFrame for validation set, target variable {target}:")
    print(df_val.head())

    print(f"\nSample DataFrame for test set, target variable {target}:")
    print(df_test.head())
# Out:
# Sample DataFrame for train set, target variable V:
#                                                 Text  True_V  Predicted_V
# 0                                    asean talks end    3.00     3.025087
# 1                 antibiotic ketek dangerous thought    2.50     2.604497
# 2                  death throughout death everywhere    2.30     2.774299
# 3  fascinating collection artifacts pertaining sh...    3.56     3.456694
# 4  rat pack originally frank sinatra dean martin ...    3.00     2.977993
#
# Sample DataFrame for validation set, target variable V:
#                                                 Text  True_V  Predicted_V
# 0                                   could free tasha    3.10     2.998966
# 1  differences western native perceptions lead co...    2.90     2.898335
# 2                 going shed little blood worry none    3.00     2.493343
# 3              simplicity dress seen mark modern man    3.11     2.954341
# 4                                          100 house    3.00     2.959018
#
# Sample DataFrame for test set, target variable V:
#                                                 Text  True_V  Predicted_V
# 0                                             silent     2.9     2.949010
# 1  overriding governor tony knowles veto ignoring...     2.6     2.738124
# 2  backwards recapitulation technique bartók empl...     3.0     3.008169
# 3                                    maybe month two     2.9     2.914372
# 4  marched regiments practiced ranks followed lea...     3.0     3.036826
#
# Sample DataFrame for train set, target variable A:
#                                                 Text  True_A  Predicted_A
# 0                                    asean talks end    2.70     3.049218
# 1                 antibiotic ketek dangerous thought    3.10     3.202289
# 2                  death throughout death everywhere    3.10     3.179900
# 3  fascinating collection artifacts pertaining sh...    3.33     2.948045
# 4  rat pack originally frank sinatra dean martin ...    3.00     3.058934
#
# Sample DataFrame for validation set, target variable A:
#                                                 Text  True_A  Predicted_A
# 0                                   could free tasha    3.10     3.097817
# 1  differences western native perceptions lead co...    2.90     3.074014
# 2                 going shed little blood worry none    3.43     3.233477
# 3              simplicity dress seen mark modern man    3.00     3.107518
# 4                                          100 house    3.20     3.095093
#
# Sample DataFrame for test set, target variable A:
#                                                 Text  True_A  Predicted_A
# 0                                             silent    2.20     3.123796
# 1  overriding governor tony knowles veto ignoring...    3.20     3.138387
# 2  backwards recapitulation technique bartók empl...    2.86     3.043661
# 3                                    maybe month two    2.70     3.093401
# 4  marched regiments practiced ranks followed lea...    2.78     3.034236
#
# Sample DataFrame for train set, target variable D:
#                                                 Text  True_D  Predicted_D
# 0                                    asean talks end    3.10     3.076557
# 1                 antibiotic ketek dangerous thought    2.80     2.864146
# 2                  death throughout death everywhere    2.80     2.962157
# 3  fascinating collection artifacts pertaining sh...    3.11     3.239324
# 4  rat pack originally frank sinatra dean martin ...    3.00     3.046442
#
# Sample DataFrame for validation set, target variable D:
#                                                 Text  True_D  Predicted_D
# 0                                   could free tasha    3.80     3.048693
# 1  differences western native perceptions lead co...    2.90     3.017208
# 2                 going shed little blood worry none    3.43     2.810843
# 3              simplicity dress seen mark modern man    3.22     3.048347
# 4                                          100 house    3.10     3.047388
#
# Sample DataFrame for test set, target variable D:
#                                                 Text  True_D  Predicted_D
# 0                                             silent     2.9     3.046337
# 1  overriding governor tony knowles veto ignoring...     2.9     2.927999
# 2  backwards recapitulation technique bartók empl...     3.0     3.057785
# 3                                    maybe month two     3.1     3.021639
# 4  marched regiments practiced ranks followed lea...     3.0     3.069957

# %%
# Save DataFrames to CSV files
df_train.to_csv(f'train_{target}_comparison_lstm_VAD.csv', index=False)
df_val.to_csv(f'val_{target}_comparison_lstm_VAD.csv', index=False)
df_test.to_csv(f'test_{target}_comparison_lstm_VAD.csv', index=False)
